# %% [markdown]
# # Analyzing My Spotify Streaming History

# %% [markdown]
# Spotify's "Spotify.me" feature - access @ https://spotify.me/en - provides a snapshot of your Spotify listening history. Under GDPR, Spotify allows the export of all of your streaming history (saved for as long as you've been a Spotify user). I downloaded my streaming history - and proceeded to run an analysis on when I listen to music, what I listen to, and how it fits in with the rest of my life.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from loader import SpotifyAPI
from dateutil.parser import parse
from pytz import timezone
from datetime import timedelta
import pytz
from datetime import datetime
from collections import defaultdict
import plotly.graph_objects as go
import plotly.express as px
import pandas as pd
import plotly
plotly.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
spotify = SpotifyAPI()

# %%
spotify.help()
# Out:
#         Available Features:
#         • load_searches (71 records)
#         • load_streaming (22020 records)
#         • load_tracks (773 records)

# %%
def range_axis(start_date, end_date):
    X = []
    delta = timedelta(days=1)
    while start_date <= end_date:
        ts = start_date.strftime('%Y-%m-%d')
        X.append(ts)
        start_date += delta
    return sorted(X)

def range_axis_months(start_date, end_date):
    r = range_axis(start_date, end_date)
    r = np.unique([x[:7] for x in r]) # remove the --d part
    return r

def date_bucket(dt):
    return dt.strftime("%Y-%m-%d")

def day_axis():
    X = []
    start_date = datetime.now()
    end_date = start_date + timedelta(days=1)
    delta = timedelta(minutes=1)
    while start_date <= end_date:
        ts = start_date.strftime('%H:%M')
        X.append(ts)
        start_date += delta
    return sorted(X)

def time_bucket(dt):
    return dt.strftime("%H:%M")

def plot(X, y, title, xaxis='', yaxis=''):
    fig = go.Figure(data=[go.Scatter(x=X, y=y, line_shape='linear')])
    fig.update_layout(
        title=title,
        yaxis_title=yaxis,
        xaxis_title=xaxis,
        font=dict(size=12)
    )
    fig.show()

# %% [markdown]
# ### Extracting Time-Relevant Information

# %%
actions = []

for search in spotify.load_searches():
    dt = parse(search.get('searchTime'), fuzzy=True, ignoretz=True)
    dt = pytz.utc.localize(dt)
    dt = dt.astimezone(timezone('US/Pacific'))
    actions.append((dt, 'search', search))
    
    
for track in spotify.load_streaming():
    dt = parse(track.get('endTime'), fuzzy=True, ignoretz=True)
    dt = pytz.utc.localize(dt)
    dt = dt.astimezone(timezone('US/Pacific'))
    actions.append((dt, 'stream', track))

# %%
actions = list(sorted(actions, key=lambda a : a[0]))

# %%
# # Filter to Time in the USA for Testing Purposes (we don't have DateTime accurate yet)
# actions = list(filter(lambda a : a[0].year == 2019 and a[0].month < 12 and a[0].month > 8, actions))

# %% [markdown]
# ### Analyze Historical Usage
# How has my Spotify streaming frequency changed over time?

# %%
data = defaultdict(int)

for action in actions:
    dt = action[0]
    bucket = date_bucket(dt)
    data[bucket] += 1
    
X = range_axis(actions[0][0], actions[-1][0])
y = [data[bucket] for bucket in X]

plot(X, y, title='Spotify Streaming over All Time', xaxis='Time', yaxis='Count')
# Out:
# <div>
#
#
#             <div id="fd629861-f6d2-4e4f-9c8c-1d493860d02d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fd629861-f6d2-4e4f-9c8c-1d493860d02d")) {
#                     Plotly.newPlot(
#                         'fd629861-f6d2-4e4f-9c8c-1d493860d02d',
#                         [{"line": {"shape": "linear"}, "type": "scatter", "x": ["2018-12-16", "2018-12-17", "2018-12-18", "2018-12-19", "2018-12-20", "2018-12-21", "2018-12-22", "2018-12-23", "2018-12-24", "2018-12-25", "2018-12-26", "2018-12-27", "2018-12-28", "2018-12-29", "2018-12-30", "2018-12-31", "2019-01-01", "2019-01-02", "2019-01-03", "2019-01-04", "2019-01-05", "2019-01-06", "2019-01-07", "2019-01-08", "2019-01-09", "2019-01-10", "2019-01-11", "2019-01-12", "2019-01-13", "2019-01-14", "2019-01-15", "2019-01-16", "2019-01-17", "2019-01-18", "2019-01-19", "2019-01-20", "2019-01-21", "2019-01-22", "2019-01-23", "2019-01-24", "2019-01-25", "2019-01-26", "2019-01-27", "2019-01-28", "2019-01-29", "2019-01-30", "2019-01-31", "2019-02-01", "2019-02-02", "2019-02-03", "2019-02-04", "2019-02-05", "2019-02-06", "2019-02-07", "2019-02-08", "2019-02-09", "2019-02-10", "2019-02-11", "2019-02-12", "2019-02-13", "2019-02-14", "2019-02-15", "2019-02-16", "2019-02-17", "2019-02-18", "2019-02-19", "2019-02-20", "2019-02-21", "2019-02-22", "2019-02-23", "2019-02-24", "2019-02-25", "2019-02-26", "2019-02-27", "2019-02-28", "2019-03-01", "2019-03-02", "2019-03-03", "2019-03-04", "2019-03-05", "2019-03-06", "2019-03-07", "2019-03-08", "2019-03-09", "2019-03-10", "2019-03-11", "2019-03-12", "2019-03-13", "2019-03-14", "2019-03-15", "2019-03-16", "2019-03-17", "2019-03-18", "2019-03-19", "2019-03-20", "2019-03-21", "2019-03-22", "2019-03-23", "2019-03-24", "2019-03-25", "2019-03-26", "2019-03-27", "2019-03-28", "2019-03-29", "2019-03-30", "2019-03-31", "2019-04-01", "2019-04-02", "2019-04-03", "2019-04-04", "2019-04-05", "2019-04-06", "2019-04-07", "2019-04-08", "2019-04-09", "2019-04-10", "2019-04-11", "2019-04-12", "2019-04-13", "2019-04-14", "2019-04-15", "2019-04-16", "2019-04-17", "2019-04-18", "2019-04-19", "2019-04-20", "2019-04-21", "2019-04-22", "2019-04-23", "2019-04-24", "2019-04-25", "2019-04-26", "2019-04-27", "2019-04-28", "2019-04-29", "2019-04-30", "2019-05-01", "2019-05-02", "2019-05-03", "2019-05-04", "2019-05-05", "2019-05-06", "2019-05-07", "2019-05-08", "2019-05-09", "2019-05-10", "2019-05-11", "2019-05-12", "2019-05-13", "2019-05-14", "2019-05-15", "2019-05-16", "2019-05-17", "2019-05-18", "2019-05-19", "2019-05-20", "2019-05-21", "2019-05-22", "2019-05-23", "2019-05-24", "2019-05-25", "2019-05-26", "2019-05-27", "2019-05-28", "2019-05-29", "2019-05-30", "2019-05-31", "2019-06-01", "2019-06-02", "2019-06-03", "2019-06-04", "2019-06-05", "2019-06-06", "2019-06-07", "2019-06-08", "2019-06-09", "2019-06-10", "2019-06-11", "2019-06-12", "2019-06-13", "2019-06-14", "2019-06-15", "2019-06-16", "2019-06-17", "2019-06-18", "2019-06-19", "2019-06-20", "2019-06-21", "2019-06-22", "2019-06-23", "2019-06-24", "2019-06-25", "2019-06-26", "2019-06-27", "2019-06-28", "2019-06-29", "2019-06-30", "2019-07-01", "2019-07-02", "2019-07-03", "2019-07-04", "2019-07-05", "2019-07-06", "2019-07-07", "2019-07-08", "2019-07-09", "2019-07-10", "2019-07-11", "2019-07-12", "2019-07-13", "2019-07-14", "2019-07-15", "2019-07-16", "2019-07-17", "2019-07-18", "2019-07-19", "2019-07-20", "2019-07-21", "2019-07-22", "2019-07-23", "2019-07-24", "2019-07-25", "2019-07-26", "2019-07-27", "2019-07-28", "2019-07-29", "2019-07-30", "2019-07-31", "2019-08-01", "2019-08-02", "2019-08-03", "2019-08-04", "2019-08-05", "2019-08-06", "2019-08-07", "2019-08-08", "2019-08-09", "2019-08-10", "2019-08-11", "2019-08-12", "2019-08-13", "2019-08-14", "2019-08-15", "2019-08-16", "2019-08-17", "2019-08-18", "2019-08-19", "2019-08-20", "2019-08-21", "2019-08-22", "2019-08-23", "2019-08-24", "2019-08-25", "2019-08-26", "2019-08-27", "2019-08-28", "2019-08-29", "2019-08-30", "2019-08-31", "2019-09-01", "2019-09-02", "2019-09-03", "2019-09-04", "2019-09-05", "2019-09-06", "2019-09-07", "2019-09-08", "2019-09-09", "2019-09-10", "2019-09-11", "2019-09-12", "2019-09-13", "2019-09-14", "2019-09-15", "2019-09-16", "2019-09-17", "2019-09-18", "2019-09-19", "2019-09-20", "2019-09-21",  ...
#                         {"font": {"size": 12}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.

# %% [markdown]
# ### Analyze Daily Usage
# When, during the day, do I listen to Spotify?

# %%
data = defaultdict(int)

for action in actions:
    data[time_bucket(action[0])] += 1
    
X = day_axis()
y = [data[bucket] for bucket in X]
plot(X, y, title='Spotify Streaming over Day', xaxis='Time', yaxis='Count')
# Out:
# <div>
#
#
#             <div id="c93dc865-f413-4deb-bb44-365a5b93de12" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c93dc865-f413-4deb-bb44-365a5b93de12")) {
#                     Plotly.newPlot(
#                         'c93dc865-f413-4deb-bb44-365a5b93de12',
#                         [{"line": {"shape": "linear"}, "type": "scatter", "x": ["00:00", "00:01", "00:02", "00:03", "00:04", "00:05", "00:06", "00:07", "00:08", "00:09", "00:10", "00:11", "00:12", "00:13", "00:14", "00:15", "00:16", "00:17", "00:18", "00:19", "00:20", "00:21", "00:22", "00:23", "00:24", "00:25", "00:26", "00:27", "00:28", "00:29", "00:30", "00:31", "00:32", "00:33", "00:34", "00:35", "00:36", "00:37", "00:38", "00:39", "00:40", "00:41", "00:42", "00:43", "00:44", "00:45", "00:46", "00:47", "00:48", "00:49", "00:50", "00:51", "00:52", "00:53", "00:54", "00:55", "00:56", "00:57", "00:58", "00:59", "01:00", "01:01", "01:02", "01:03", "01:04", "01:05", "01:06", "01:07", "01:08", "01:09", "01:10", "01:11", "01:12", "01:13", "01:14", "01:15", "01:16", "01:17", "01:18", "01:19", "01:20", "01:21", "01:22", "01:23", "01:24", "01:25", "01:26", "01:27", "01:28", "01:29", "01:30", "01:31", "01:32", "01:33", "01:34", "01:35", "01:36", "01:37", "01:38", "01:39", "01:40", "01:41", "01:42", "01:43", "01:44", "01:45", "01:46", "01:47", "01:48", "01:49", "01:50", "01:51", "01:52", "01:53", "01:54", "01:55", "01:56", "01:57", "01:58", "01:59", "02:00", "02:01", "02:02", "02:03", "02:04", "02:05", "02:06", "02:07", "02:08", "02:09", "02:10", "02:11", "02:12", "02:13", "02:14", "02:15", "02:16", "02:17", "02:18", "02:19", "02:20", "02:21", "02:22", "02:23", "02:24", "02:25", "02:26", "02:27", "02:28", "02:29", "02:30", "02:31", "02:32", "02:33", "02:34", "02:35", "02:36", "02:37", "02:38", "02:39", "02:40", "02:41", "02:42", "02:43", "02:44", "02:45", "02:46", "02:47", "02:48", "02:49", "02:50", "02:51", "02:52", "02:53", "02:54", "02:55", "02:56", "02:57", "02:58", "02:59", "03:00", "03:01", "03:02", "03:03", "03:04", "03:05", "03:06", "03:07", "03:08", "03:09", "03:10", "03:11", "03:12", "03:13", "03:14", "03:15", "03:16", "03:17", "03:18", "03:19", "03:20", "03:21", "03:22", "03:23", "03:24", "03:25", "03:26", "03:27", "03:28", "03:29", "03:30", "03:31", "03:32", "03:33", "03:34", "03:35", "03:36", "03:37", "03:38", "03:39", "03:40", "03:41", "03:42", "03:43", "03:44", "03:45", "03:46", "03:47", "03:48", "03:49", "03:50", "03:51", "03:52", "03:53", "03:54", "03:55", "03:56", "03:57", "03:58", "03:59", "04:00", "04:01", "04:02", "04:03", "04:04", "04:05", "04:06", "04:07", "04:08", "04:09", "04:10", "04:11", "04:12", "04:13", "04:14", "04:15", "04:16", "04:17", "04:18", "04:19", "04:20", "04:21", "04:22", "04:23", "04:24", "04:25", "04:26", "04:27", "04:28", "04:29", "04:30", "04:31", "04:32", "04:33", "04:34", "04:35", "04:36", "04:37", "04:38", "04:39", "04:40", "04:41", "04:42", "04:43", "04:44", "04:45", "04:46", "04:47", "04:48", "04:49", "04:50", "04:51", "04:52", "04:53", "04:54", "04:55", "04:56", "04:57", "04:58", "04:59", "05:00", "05:01", "05:02", "05:03", "05:04", "05:05", "05:06", "05:07", "05:08", "05:09", "05:10", "05:11", "05:12", "05:13", "05:14", "05:15", "05:16", "05:17", "05:18", "05:19", "05:20", "05:21", "05:22", "05:23", "05:24", "05:25", "05:26", "05:27", "05:28", "05:29", "05:30", "05:31", "05:32", "05:33", "05:34", "05:35", "05:36", "05:37", "05:38", "05:39", "05:40", "05:41", "05:42", "05:43", "05:44", "05:45", "05:46", "05:47", "05:48", "05:49", "05:50", "05:51", "05:52", "05:53", "05:54", "05:55", "05:56", "05:57", "05:58", "05:59", "06:00", "06:01", "06:02", "06:03", "06:04", "06:05", "06:06", "06:07", "06:08", "06:09", "06:10", "06:11", "06:12", "06:13", "06:14", "06:15", "06:16", "06:17", "06:18", "06:19", "06:20", "06:21", "06:22", "06:23", "06:24", "06:25", "06:26", "06:27", "06:28", "06:29", "06:30", "06:31", "06:32", "06:33", "06:34", "06:35", "06:36", "06:37", "06:38", "06:39", "06:40", "06:41", "06:42", "06:43", "06:44", "06:45", "06:46", "06:47", "06:48", "06:49", "06:50", "06:51", "06:52", "06:53", "06:54", "06:55", "06:56", "06:57", "06:58", "06:59", "07:00", "07:01", "07:02", "07:03", "07:04", "07:05", "07:06", "07:07", "07:08", "07:09", "07:10", "07:11", "07:12", "07:13", "07:14", "07:1 ...

# %% [markdown]
# ### Most Popular Tracks & Artists
# What do I listen to the most?

# %%
df = pd.DataFrame.from_dict(spotify.load_streaming())

# %%
favorite_tracks = df.groupby('trackName').sum().sort_values('msPlayed', ascending=False)
favorite_tracks.head(15)
# Out:
#                                       msPlayed
# trackName
# You & Me                              11353946
# Daylight                              11202478
# Beautiful Creatures (feat. MAX)       10216498
# A Thousand Years                       9824923
# Speechless (Full)                      9735994
# Dreamer                                9429627
# Africa                                 8506608
# Say Love                               8503985
# Agar Tum Saath Ho / Treat You Better   8391912
# Sweet Caroline                         8123963
# Viva La Vida                           8070796
# Home                                   8053762
# Happier                                7732205
# Viva La Vida / Jashn-e-Bahara          7702294
# Trumpets                               7633487

# %%
favorite_artists = df.groupby('artistName').sum().sort_values('msPlayed', ascending=False)
favorite_artists.head(15)
# Out:
#                    msPlayed
# artistName
# Penn Masala        76843387
# Lauv               52911093
# Coldplay           50489435
# Alan Silvestri     44240044
# James TW           35677742
# Maroon 5           35513986
# Avicii             35182648
# ILLENIUM           34905130
# Michael Giacchino  29406494
# Hans Zimmer        28492686
# John Williams      25761057
# Dean Lewis         25560016
# Alexandre Desplat  24648856
# Imagine Dragons    24342501
# Martin Garrix      22212596

# %% [markdown]
# ## Comparision to All Music

# %% [markdown]
# Let's take a look at these on a plot. It appears that the difference between songs that I really enjoy and those that fit into the "general" category is striking; there's a sharp curve for both of these graphs.

# %%
plot(favorite_artists.index,favorite_artists['msPlayed'], title="My Favorite Artists", xaxis='Artist Name', yaxis='ms played')
# Out:
# <div>
#
#
#             <div id="164e7546-19bf-427a-b425-676ff90fbf91" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("164e7546-19bf-427a-b425-676ff90fbf91")) {
#                     Plotly.newPlot(
#                         '164e7546-19bf-427a-b425-676ff90fbf91',
#                         [{"line": {"shape": "linear"}, "type": "scatter", "x": ["Penn Masala", "Lauv", "Coldplay", "Alan Silvestri", "James TW", "Maroon 5", "Avicii", "ILLENIUM", "Michael Giacchino", "Hans Zimmer", "John Williams", "Dean Lewis", "Alexandre Desplat", "Imagine Dragons", "Martin Garrix", "Vance Joy", "Kygo", "Naomi Scott", "Gryffin", "Shawn Mendes", "Ed Sheeran", "Noah Kahan", "OneRepublic", "Kirill Richter", "The Script", "5 Seconds of Summer", "Electric Light Orchestra", "Mumford & Sons", "Sam Smith", "James Arthur", "Vigiland", "Jason Derulo", "Alesso", "Steve Jablonsky", "Ramin Djawadi", "Fleetwood Mac", "Jason Mraz", "James Bay", "Marshmello", "TOTO", "Brian Tyler", "Alan Menken", "Neil Diamond", "The Chainsmokers", "Christina Perri", "Axwell /\\ Ingrosso", "A R I Z O N A", "Jonas Blue", "The Vamps", "Daryl Hall & John Oates", "John Powell", "Lewis Capaldi", "ZAYN", "Khalid", "Hailee Steinfeld", "Anne Dudley", "fun.", "Cheat Codes", "Craig Armstrong", "Rachel Portman", "Demi Lovato", "George Ezra", "Tungevaag & Raaban", "Gavin James", "Bastille", "Cody Simpson", "David Arnold & Michael Price", "Wrabel", "Post Malone", "Prague Cello Quartet", "Why Don't We", "The City of Prague Philharmonic Orchestra", "Justin Hurwitz", "Edward Sharpe & The Magnetic Zeros", "Taylor Swift", "Sad Puppy", "Cash Cash", "Zedd", "Billy Joel", "Rita Ora", "Brass D\u00e9lirium", "Journey", "Matoma", "Jonas Brothers", "Kansas", "Sonu Nigam", "James Horner", "Calum Scott", "Train", "Elton John", "NOTD", "MAX", "Lady Gaga", "X Ambassadors", "FRENSHIP", "Michael Kamen", "Rupert Gregson-Williams", "Jack & Jack", "P!nk", "The Lumineers", "James Newton Howard", "MKTO", "Ellie Goulding", "The Wanted", "The Piano Guys", "David Guetta", "John Mayer", "Jess Glynne", "Mina Alali", "Eagles", "Nicholas Hooper", "WALK THE MOON", "Trevor Rabin", "Carter Burwell", "Andy Grammer", "Matt Maeson", "Kodaline", "Sia", "Guns N' Roses", "Avril Lavigne", "Pinar Toprak", "BANNERS", "Zara Larsson", "Alessia Cara", "gnash", "Dexys Midnight Runners", "Stevie Nicks", "Alan Walker", "Selena Gomez", "Charlie Puth", "One Direction", "Niall Horan", "Marc Shaiman", "2CELLOS", "Van Morrison", "Mike Perry", "Lostboycrow", "Noah Cyrus", "Lewis Watson", "Disclosure", "Hugh Jackman", "Life of Dillon", "Calvin Harris", "Kenny Loggins", "Harry Gregson-Williams", "The Beatles", "Paul Simon", "Patrick Doyle", "John Legend", "Foreigner", "Zack Hemsey", "Justin Timberlake", "Ariana Grande", "L\u00c9ON", "Bob Dylan", "The 1975", "Mt. Joy", "Clean Bandit", "ABBA", "Tritonal", "Stevie Wonder", "Of Monsters and Men", "Felix Jaehn", "Lukas Graham", "Beyonc\u00e9", "Clint Mansell", "Jerry Goldsmith", "Mako", "The Rolling Stones", "Jack Johnson", "La La Land Cast", "Mena Massoud", "Backstreet Boys", "Nicky Jam", "Daya", "Emma Stone", "Paul McCartney", "Wahlstedt", "Arijit Singh", "Quinn XCII", "Zac Efron", "Steve Aoki", "Shaan", "The Doobie Brothers", "Anne-Marie", "Bruce Hornsby", "Earth, Wind & Fire", "Kristen Anderson-Lopez", "Stephen Warbeck", "DubVision", "Smallpools", "Galantis", "American Authors", "Sam Fischer", "Ryland James", "Pat Benatar", "Matt and Kim", "Miley Cyrus", "Julia Michaels", "Adele", "Ansel Elgort", "Lord Huron", "Gabrielle Aplin", "Bon Jovi", "Bruno Mars", "Will Smith", "MAGIC!", "The Goo Goo Dolls", "Diamond Eyes", "Rusted Root", "Heart", "Lost Kings", "Seeb", "James Vincent McMorrow", "Charlotte Lawrence", "Toploader", "Hardwell", "Bear McCreary", "Shoffy", "Ruth B.", "Tungevaag", "DNCE", "Owl City", "Cold War Kids", "Dermot Kennedy", "Idina Menzel", "Bebe Rexha", "Landon Austin", "Enrique Iglesias", "Farhan Akhtar", "Akon", "Thomas Newman", "Rihanna", "Saint Motel", "Don Diablo", "Years & Years", "The La's", "Europe", "Keala Settle", "Armin van Buuren", "Queen", "Kesha", "Plain White T's", "DJ Snake", "James Blunt", "AJR", "Leon Bridges", "JP Cooper", "The Killers", "Panic! At The Disco", "Vishal-Shekhar", "Passenger", "Maggie Lindemann", "Ludvigsson", "Olly ...

# %%
plot(favorite_tracks.index,favorite_tracks['msPlayed'], title="My Favorite Tracks", yaxis='ms played')
# Out:
# <div>
#
#
#             <div id="8f3a74bd-0273-401f-b0f6-d498436fc7ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8f3a74bd-0273-401f-b0f6-d498436fc7ce")) {
#                     Plotly.newPlot(
#                         '8f3a74bd-0273-401f-b0f6-d498436fc7ce',
#                         [{"line": {"shape": "linear"}, "type": "scatter", "x": ["You & Me", "Daylight", "Beautiful Creatures (feat. MAX)", "A Thousand Years", "Speechless (Full)", "Dreamer", "Africa", "Say Love", "Agar Tum Saath Ho / Treat You Better", "Sweet Caroline", "Viva La Vida", "Home", "Happier", "Viva La Vida / Jashn-e-Bahara", "Trumpets", "Wake Me Up", "I Like Me Better", "Where Angels Fear to Tread - FOX Sports Original Soundtrack", "False Alarm", "No One Compares To You", "Only The Beginning Of The Adventure (From \"The Chronicles Of Narnia: The Lion, The Witch And The Wardrobe\")", "Carry on Wayward Son", "The Real Hero", "Maneater", "Sweet Child O' Mine", "Come On Eileen", "Only You", "Mr. Blue Sky", "Happy Now", "Don't Stop Believin'", "Youngblood", "Never Not", "Rewrite The Stars (with James Arthur & Anne-Marie)", "dear insecurity (feat. ben abraham)", "In The Middle", "Up With End Credits", "Only Fools Fall in Love", "What She Wants", "Arrival to Earth", "Scared to Be Lonely", "Soldier", "Take It Easy - 2013 Remaster", "Used To Love (with Dean Lewis)", "The Village", "All I Am", "Feel Good (feat. Daya)", "Where It All Goes", "Paradise", "Incredits 2", "Superhero", "Let Me Go (with Alesso, Florida Georgia Line & watt)", "Hey, Soul Sister", "I Found A Girl", "Renegades", "Higher Love", "Bhagwaan Hai Kahan Re Tu", "Sink", "Jenny Jenkins", "Saturday Nights", "There's No Way (feat. Julia Michaels)", "Let You Love Me", "Breathe", "You Can Call Me Al", "There She Goes", "REMEDY", "What I Like About You (feat. Theresa Rex)", "When We Were Young", "How Can I Forget", "If You Ever Come Back", "A Million Dreams", "Portals", "Footloose", "Fawkes the Phoenix", "little light - acoustic version", "Edge of Seventeen - 2016 Remaster", "Tightrope", "High Hopes", "Enemies", "The Imitation Game", "Freaking Out", "Isn't She Lovely", "Shallow - Radio Edit", "Hero (feat. Christina Perri) - Deep Mix", "Another Day Of Sun", "Hell Hath No Fury", "Shut Up and Dance", "Sucker", "Memories", "El Perd\u00f3n", "Quarter Past Midnight - One Eyed Jack's Session", "Fly Like Iron Man", "Main on End", "Race to Big Ben", "Superheroes", "Be Alright", "Mind Heist: Evolution", "All of Me", "Some Nights", "Me Before You Orchestral", "Rewrite The Stars", "Still New York", "Nervous - The Ooh Song/Mark McCabe Remix", "Say Something", "Stay With Me", "A Whole New World", "Don't Go Breaking My Heart", "September", "Cringe", "A Whole New World (End Title) - From \"Aladdin\"", "If You Ever Wanna Be In Love - James Bay Spotify Session 2015", "2002", "Someone To You", "Latch", "In My Head", "This City", "Never Seen Anything \"Quite Like You\" - Acoustic", "Let It Go - Demi Lovato Version / Instrumental Karaoke", "Uptown Girl", "Listen to the Music", "A Window to the Past", "Piano Man", "Hold Back The River", "The Middle", "The Nights", "Coming Home", "Million Bucks", "You Make My Dreams", "Chasing Fire", "i'm so tired...", "Girls Like You (feat. Cardi B)", "Brown Eyed Girl", "Wish U Were Here - Acoustic", "Hold the Line", "When You Love Someone", "Livin' On A Prayer", "Tessa", "Se\u00f1orita", "Hurt Somebody (With Julia Michaels)", "Everything", "Waves", "Upside Down", "Good Things Fall Apart (with Jon Bellion)", "I Want to Know What Love Is - 1999 Remaster", "Launch", "Someone In The Crowd", "Because of Me", "Smoke Clears", "Head Above Water", "Flicker", "Need You Now", "Anywhere", "Without You (feat. Sandro Cavazza)", "You Are The Reason", "Take Me Away", "Dancing in the Moonlight - 2001 Remix", "Unbelievable", "The Gambler", "Finest Hour (feat. Abir)", "In My Blood", "Rise Up", "Down / Desi Girl", "Bad Liar", "Dusk Till Dawn - Radio Edit", "Love Someone", "Thief", "All For Love", "Lights Down Low", "Young Blood", "Back To You - From 13 Reasons Why \u2013 Season 2 Soundtrack", "What About Us", "Remind Me to Forget", "Chaar Kadam", "If It Wasn't For You", "Friday Night\u202c\u202c\u202c", "Somebody", "Marry You", "Ratatouille Main Theme", "Stay - Tere Bina",  ...

# %% [markdown]
# ## Top Tracks Over Time

# %%
top = favorite_tracks.head(20).index.to_list()
top = df[df.trackName.isin(top)]
top = top.assign(endTime=lambda df: df['endTime'].apply(lambda x : x[:10]))
top.head()
# Out:
#      artistName     endTime  msPlayed                        trackName
# 41   Marshmello  2018-12-17    187132                          Happier
# 66     ILLENIUM  2018-12-17    240508  Beautiful Creatures (feat. MAX)
# 99     ILLENIUM  2018-12-17    240508  Beautiful Creatures (feat. MAX)
# 129    James TW  2018-12-19    219440                         Say Love
# 148    ILLENIUM  2018-12-19    240508  Beautiful Creatures (feat. MAX)

# %%
def get_data(tracker):
    data_cumulative = []
    data_monthly = []
    for artist, cum_dict in tracker.items():
        y_cum = []
        y_daily = []
        cum_ms = 0
        for dt in X:
            cum_ms += cum_dict.get(dt, 0)
            y_cum.append(cum_ms)

        y_months = [sum([v for k, v in cum_dict.items() if month in k]) for month in X_months]
        data_cumulative.append(go.Scatter(x=X, y=y_cum, name=artist, line_shape='spline'))
        data_monthly.append(go.Scatter(x=X_months, y=y_months, name=artist, line_shape='spline'))
        
    return data_cumulative, data_monthly

def plot(data, title):
    fig = go.Figure(data=data)
    fig.update_layout(
        title=title,
        yaxis_title='Total Time Listened To',
        xaxis_title='Time',
        font=dict(size=12)
    )
    fig.show()

# %%
artist_tracker = defaultdict(dict)
track_tracker = defaultdict(dict)

for i, row in top.iterrows():
    dt = row.get('endTime')
    artist = row.get('artistName')[:18]
    track = row.get('trackName')[:18]
    ms = int(row.get('msPlayed'))
    artist_tracker[artist][dt] = artist_tracker[artist].setdefault(dt, 0) + ms
    track_tracker[track][dt] = track_tracker[track].setdefault(dt, 0) + ms
    
r = list(sorted(top['endTime']))
X = range_axis(parse(r[0]), parse(r[-1]))
X_months = range_axis_months(parse(r[0]), parse(r[-1]))

# %%
artists_cum, artists_mon = get_data(artist_tracker)
tracks_cum, tracks_mon = get_data(track_tracker)

plot(artists_cum, 'Artists over Time (Cumulative)')
plot(artists_mon, 'Artists over Time (Monthly)')
plot(tracks_cum, 'Tracks over Time (Monthly)')
plot(tracks_mon, 'Tracks over Time (Monthly)')
# Out:
# <div>
#
#
#             <div id="3693a828-185b-45a4-be0b-2bd0884f5b21" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3693a828-185b-45a4-be0b-2bd0884f5b21")) {
#                     Plotly.newPlot(
#                         '3693a828-185b-45a4-be0b-2bd0884f5b21',
#                         [{"line": {"shape": "spline"}, "name": "Marshmello", "type": "scatter", "x": ["2018-12-17", "2018-12-18", "2018-12-19", "2018-12-20", "2018-12-21", "2018-12-22", "2018-12-23", "2018-12-24", "2018-12-25", "2018-12-26", "2018-12-27", "2018-12-28", "2018-12-29", "2018-12-30", "2018-12-31", "2019-01-01", "2019-01-02", "2019-01-03", "2019-01-04", "2019-01-05", "2019-01-06", "2019-01-07", "2019-01-08", "2019-01-09", "2019-01-10", "2019-01-11", "2019-01-12", "2019-01-13", "2019-01-14", "2019-01-15", "2019-01-16", "2019-01-17", "2019-01-18", "2019-01-19", "2019-01-20", "2019-01-21", "2019-01-22", "2019-01-23", "2019-01-24", "2019-01-25", "2019-01-26", "2019-01-27", "2019-01-28", "2019-01-29", "2019-01-30", "2019-01-31", "2019-02-01", "2019-02-02", "2019-02-03", "2019-02-04", "2019-02-05", "2019-02-06", "2019-02-07", "2019-02-08", "2019-02-09", "2019-02-10", "2019-02-11", "2019-02-12", "2019-02-13", "2019-02-14", "2019-02-15", "2019-02-16", "2019-02-17", "2019-02-18", "2019-02-19", "2019-02-20", "2019-02-21", "2019-02-22", "2019-02-23", "2019-02-24", "2019-02-25", "2019-02-26", "2019-02-27", "2019-02-28", "2019-03-01", "2019-03-02", "2019-03-03", "2019-03-04", "2019-03-05", "2019-03-06", "2019-03-07", "2019-03-08", "2019-03-09", "2019-03-10", "2019-03-11", "2019-03-12", "2019-03-13", "2019-03-14", "2019-03-15", "2019-03-16", "2019-03-17", "2019-03-18", "2019-03-19", "2019-03-20", "2019-03-21", "2019-03-22", "2019-03-23", "2019-03-24", "2019-03-25", "2019-03-26", "2019-03-27", "2019-03-28", "2019-03-29", "2019-03-30", "2019-03-31", "2019-04-01", "2019-04-02", "2019-04-03", "2019-04-04", "2019-04-05", "2019-04-06", "2019-04-07", "2019-04-08", "2019-04-09", "2019-04-10", "2019-04-11", "2019-04-12", "2019-04-13", "2019-04-14", "2019-04-15", "2019-04-16", "2019-04-17", "2019-04-18", "2019-04-19", "2019-04-20", "2019-04-21", "2019-04-22", "2019-04-23", "2019-04-24", "2019-04-25", "2019-04-26", "2019-04-27", "2019-04-28", "2019-04-29", "2019-04-30", "2019-05-01", "2019-05-02", "2019-05-03", "2019-05-04", "2019-05-05", "2019-05-06", "2019-05-07", "2019-05-08", "2019-05-09", "2019-05-10", "2019-05-11", "2019-05-12", "2019-05-13", "2019-05-14", "2019-05-15", "2019-05-16", "2019-05-17", "2019-05-18", "2019-05-19", "2019-05-20", "2019-05-21", "2019-05-22", "2019-05-23", "2019-05-24", "2019-05-25", "2019-05-26", "2019-05-27", "2019-05-28", "2019-05-29", "2019-05-30", "2019-05-31", "2019-06-01", "2019-06-02", "2019-06-03", "2019-06-04", "2019-06-05", "2019-06-06", "2019-06-07", "2019-06-08", "2019-06-09", "2019-06-10", "2019-06-11", "2019-06-12", "2019-06-13", "2019-06-14", "2019-06-15", "2019-06-16", "2019-06-17", "2019-06-18", "2019-06-19", "2019-06-20", "2019-06-21", "2019-06-22", "2019-06-23", "2019-06-24", "2019-06-25", "2019-06-26", "2019-06-27", "2019-06-28", "2019-06-29", "2019-06-30", "2019-07-01", "2019-07-02", "2019-07-03", "2019-07-04", "2019-07-05", "2019-07-06", "2019-07-07", "2019-07-08", "2019-07-09", "2019-07-10", "2019-07-11", "2019-07-12", "2019-07-13", "2019-07-14", "2019-07-15", "2019-07-16", "2019-07-17", "2019-07-18", "2019-07-19", "2019-07-20", "2019-07-21", "2019-07-22", "2019-07-23", "2019-07-24", "2019-07-25", "2019-07-26", "2019-07-27", "2019-07-28", "2019-07-29", "2019-07-30", "2019-07-31", "2019-08-01", "2019-08-02", "2019-08-03", "2019-08-04", "2019-08-05", "2019-08-06", "2019-08-07", "2019-08-08", "2019-08-09", "2019-08-10", "2019-08-11", "2019-08-12", "2019-08-13", "2019-08-14", "2019-08-15", "2019-08-16", "2019-08-17", "2019-08-18", "2019-08-19", "2019-08-20", "2019-08-21", "2019-08-22", "2019-08-23", "2019-08-24", "2019-08-25", "2019-08-26", "2019-08-27", "2019-08-28", "2019-08-29", "2019-08-30", "2019-08-31", "2019-09-01", "2019-09-02", "2019-09-03", "2019-09-04", "2019-09-05", "2019-09-06", "2019-09-07", "2019-09-08", "2019-09-09", "2019-09-10", "2019-09-11", "2019-09-12", "2019-09-13", "2019-09-14", "2019-09-15", "2019-09-16", "2019-09-17", "2019-09-18", "2019-09-19", "2019-09-20", "2019- ...
# <div>
#
#
#             <div id="4e46f268-abc8-4b2d-a66f-32618d82a42a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4e46f268-abc8-4b2d-a66f-32618d82a42a")) {
#                     Plotly.newPlot(
#                         '4e46f268-abc8-4b2d-a66f-32618d82a42a',
#                         [{"line": {"shape": "spline"}, "name": "Marshmello", "type": "scatter", "x": ["2018-12", "2019-01", "2019-02", "2019-03", "2019-04", "2019-05", "2019-06", "2019-07", "2019-08", "2019-09", "2019-10", "2019-11", "2019-12"], "y": [187132, 287363, 428578, 0, 642867, 1284736, 623942, 377089, 218567, 0, 428578, 1572379, 51690]}, {"line": {"shape": "spline"}, "name": "ILLENIUM", "type": "scatter", "x": ["2018-12", "2019-01", "2019-02", "2019-03", "2019-04", "2019-05", "2019-06", "2019-07", "2019-08", "2019-09", "2019-10", "2019-11", "2019-12"], "y": [1937547, 923235, 481027, 1419420, 1260701, 703834, 242899, 0, 0, 721524, 240508, 975527, 1310276]}, {"line": {"shape": "spline"}, "name": "James TW", "type": "scatter", "x": ["2018-12", "2019-01", "2019-02", "2019-03", "2019-04", "2019-05", "2019-06", "2019-07", "2019-08", "2019-09", "2019-10", "2019-11", "2019-12"], "y": [658320, 2212350, 224093, 2877301, 1021971, 1144487, 3897376, 4573935, 1059326, 453039, 351363, 463306, 702571]}, {"line": {"shape": "spline"}, "name": "Edward Sharpe & Th", "type": "scatter", "x": ["2018-12", "2019-01", "2019-02", "2019-03", "2019-04", "2019-05", "2019-06", "2019-07", "2019-08", "2019-09", "2019-10", "2019-11", "2019-12"], "y": [810584, 2405242, 1212800, 629823, 189147, 920914, 537714, 0, 606400, 0, 0, 1980, 303081]}, {"line": {"shape": "spline"}, "name": "Neil Diamond", "type": "scatter", "x": ["2018-12", "2019-01", "2019-02", "2019-03", "2019-04", "2019-05", "2019-06", "2019-07", "2019-08", "2019-09", "2019-10", "2019-11", "2019-12"], "y": [405013, 2245503, 1113527, 1420744, 610227, 407281, 212326, 540964, 705746, 0, 202506, 202506, 57620]}, {"line": {"shape": "spline"}, "name": "Matt and Kim", "type": "scatter", "x": ["2018-12", "2019-01", "2019-02", "2019-03", "2019-04", "2019-05", "2019-06", "2019-07", "2019-08", "2019-09", "2019-10", "2019-11", "2019-12"], "y": [342666, 1201583, 993743, 171333, 514017, 172911, 2133, 0, 0, 0, 0, 0, 1813]}, {"line": {"shape": "spline"}, "name": "Coldplay", "type": "scatter", "x": ["2018-12", "2019-01", "2019-02", "2019-03", "2019-04", "2019-05", "2019-06", "2019-07", "2019-08", "2019-09", "2019-10", "2019-11", "2019-12"], "y": [155882, 1015208, 989274, 1525123, 886860, 973821, 594157, 242372, 242373, 0, 484744, 484745, 242373]}, {"line": {"shape": "spline"}, "name": "TOTO", "type": "scatter", "x": ["2018-12", "2019-01", "2019-02", "2019-03", "2019-04", "2019-05", "2019-06", "2019-07", "2019-08", "2019-09", "2019-10", "2019-11", "2019-12"], "y": [0, 2071251, 2962023, 1479465, 301233, 1486, 529255, 0, 295893, 0, 0, 295893, 295893]}, {"line": {"shape": "spline"}, "name": "Matoma", "type": "scatter", "x": ["2018-12", "2019-01", "2019-02", "2019-03", "2019-04", "2019-05", "2019-06", "2019-07", "2019-08", "2019-09", "2019-10", "2019-11", "2019-12"], "y": [0, 907024, 0, 224271, 675575, 273349, 372601, 1056453, 686766, 1121355, 829063, 672813, 94612]}, {"line": {"shape": "spline"}, "name": "Christina Perri", "type": "scatter", "x": ["2018-12", "2019-01", "2019-02", "2019-03", "2019-04", "2019-05", "2019-06", "2019-07", "2019-08", "2019-09", "2019-10", "2019-11", "2019-12"], "y": [0, 5995613, 1141644, 285120, 570240, 13747, 392959, 285120, 285120, 285120, 0, 570240, 0]}, {"line": {"shape": "spline"}, "name": "Avicii", "type": "scatter", "x": ["2018-12", "2019-01", "2019-02", "2019-03", "2019-04", "2019-05", "2019-06", "2019-07", "2019-08", "2019-09", "2019-10", "2019-11", "2019-12"], "y": [0, 991776, 494853, 247426, 583982, 1337322, 989704, 0, 494852, 0, 957762, 497940, 247426]}, {"line": {"shape": "spline"}, "name": "Lauv", "type": "scatter", "x": ["2018-12", "2019-01", "2019-02", "2019-03", "2019-04", "2019-05", "2019-06", "2019-07", "2019-08", "2019-09", "2019-10", "2019-11", "2019-12"], "y": [0, 394873, 789745, 0, 875578, 1649881, 413347, 604268, 809333, 231873, 533902, 197436, 412484]}, {"line": {"shape": "spline"}, "name": "Ysabelle Cuevas", "type": "scatter", "x": ["2018-12", "2019-01", "2019- ...
# <div>
#
#
#             <div id="edc90302-cc38-46a2-a0d9-a640aa86f7ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("edc90302-cc38-46a2-a0d9-a640aa86f7ae")) {
#                     Plotly.newPlot(
#                         'edc90302-cc38-46a2-a0d9-a640aa86f7ae',
#                         [{"line": {"shape": "spline"}, "name": "Happier", "type": "scatter", "x": ["2018-12-17", "2018-12-18", "2018-12-19", "2018-12-20", "2018-12-21", "2018-12-22", "2018-12-23", "2018-12-24", "2018-12-25", "2018-12-26", "2018-12-27", "2018-12-28", "2018-12-29", "2018-12-30", "2018-12-31", "2019-01-01", "2019-01-02", "2019-01-03", "2019-01-04", "2019-01-05", "2019-01-06", "2019-01-07", "2019-01-08", "2019-01-09", "2019-01-10", "2019-01-11", "2019-01-12", "2019-01-13", "2019-01-14", "2019-01-15", "2019-01-16", "2019-01-17", "2019-01-18", "2019-01-19", "2019-01-20", "2019-01-21", "2019-01-22", "2019-01-23", "2019-01-24", "2019-01-25", "2019-01-26", "2019-01-27", "2019-01-28", "2019-01-29", "2019-01-30", "2019-01-31", "2019-02-01", "2019-02-02", "2019-02-03", "2019-02-04", "2019-02-05", "2019-02-06", "2019-02-07", "2019-02-08", "2019-02-09", "2019-02-10", "2019-02-11", "2019-02-12", "2019-02-13", "2019-02-14", "2019-02-15", "2019-02-16", "2019-02-17", "2019-02-18", "2019-02-19", "2019-02-20", "2019-02-21", "2019-02-22", "2019-02-23", "2019-02-24", "2019-02-25", "2019-02-26", "2019-02-27", "2019-02-28", "2019-03-01", "2019-03-02", "2019-03-03", "2019-03-04", "2019-03-05", "2019-03-06", "2019-03-07", "2019-03-08", "2019-03-09", "2019-03-10", "2019-03-11", "2019-03-12", "2019-03-13", "2019-03-14", "2019-03-15", "2019-03-16", "2019-03-17", "2019-03-18", "2019-03-19", "2019-03-20", "2019-03-21", "2019-03-22", "2019-03-23", "2019-03-24", "2019-03-25", "2019-03-26", "2019-03-27", "2019-03-28", "2019-03-29", "2019-03-30", "2019-03-31", "2019-04-01", "2019-04-02", "2019-04-03", "2019-04-04", "2019-04-05", "2019-04-06", "2019-04-07", "2019-04-08", "2019-04-09", "2019-04-10", "2019-04-11", "2019-04-12", "2019-04-13", "2019-04-14", "2019-04-15", "2019-04-16", "2019-04-17", "2019-04-18", "2019-04-19", "2019-04-20", "2019-04-21", "2019-04-22", "2019-04-23", "2019-04-24", "2019-04-25", "2019-04-26", "2019-04-27", "2019-04-28", "2019-04-29", "2019-04-30", "2019-05-01", "2019-05-02", "2019-05-03", "2019-05-04", "2019-05-05", "2019-05-06", "2019-05-07", "2019-05-08", "2019-05-09", "2019-05-10", "2019-05-11", "2019-05-12", "2019-05-13", "2019-05-14", "2019-05-15", "2019-05-16", "2019-05-17", "2019-05-18", "2019-05-19", "2019-05-20", "2019-05-21", "2019-05-22", "2019-05-23", "2019-05-24", "2019-05-25", "2019-05-26", "2019-05-27", "2019-05-28", "2019-05-29", "2019-05-30", "2019-05-31", "2019-06-01", "2019-06-02", "2019-06-03", "2019-06-04", "2019-06-05", "2019-06-06", "2019-06-07", "2019-06-08", "2019-06-09", "2019-06-10", "2019-06-11", "2019-06-12", "2019-06-13", "2019-06-14", "2019-06-15", "2019-06-16", "2019-06-17", "2019-06-18", "2019-06-19", "2019-06-20", "2019-06-21", "2019-06-22", "2019-06-23", "2019-06-24", "2019-06-25", "2019-06-26", "2019-06-27", "2019-06-28", "2019-06-29", "2019-06-30", "2019-07-01", "2019-07-02", "2019-07-03", "2019-07-04", "2019-07-05", "2019-07-06", "2019-07-07", "2019-07-08", "2019-07-09", "2019-07-10", "2019-07-11", "2019-07-12", "2019-07-13", "2019-07-14", "2019-07-15", "2019-07-16", "2019-07-17", "2019-07-18", "2019-07-19", "2019-07-20", "2019-07-21", "2019-07-22", "2019-07-23", "2019-07-24", "2019-07-25", "2019-07-26", "2019-07-27", "2019-07-28", "2019-07-29", "2019-07-30", "2019-07-31", "2019-08-01", "2019-08-02", "2019-08-03", "2019-08-04", "2019-08-05", "2019-08-06", "2019-08-07", "2019-08-08", "2019-08-09", "2019-08-10", "2019-08-11", "2019-08-12", "2019-08-13", "2019-08-14", "2019-08-15", "2019-08-16", "2019-08-17", "2019-08-18", "2019-08-19", "2019-08-20", "2019-08-21", "2019-08-22", "2019-08-23", "2019-08-24", "2019-08-25", "2019-08-26", "2019-08-27", "2019-08-28", "2019-08-29", "2019-08-30", "2019-08-31", "2019-09-01", "2019-09-02", "2019-09-03", "2019-09-04", "2019-09-05", "2019-09-06", "2019-09-07", "2019-09-08", "2019-09-09", "2019-09-10", "2019-09-11", "2019-09-12", "2019-09-13", "2019-09-14", "2019-09-15", "2019-09-16", "2019-09-17", "2019-09-18", "2019-09-19", "2019-09-20", "2019-09- ...
# <div>
#
#
#             <div id="ddc4fbcf-416e-4e64-bc8c-7da8099b14ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ddc4fbcf-416e-4e64-bc8c-7da8099b14ff")) {
#                     Plotly.newPlot(
#                         'ddc4fbcf-416e-4e64-bc8c-7da8099b14ff',
#                         [{"line": {"shape": "spline"}, "name": "Happier", "type": "scatter", "x": ["2018-12", "2019-01", "2019-02", "2019-03", "2019-04", "2019-05", "2019-06", "2019-07", "2019-08", "2019-09", "2019-10", "2019-11", "2019-12"], "y": [187132, 287363, 428578, 0, 1057907, 1299324, 779009, 999649, 218567, 0, 428578, 1572379, 473719]}, {"line": {"shape": "spline"}, "name": "Beautiful Creature", "type": "scatter", "x": ["2018-12", "2019-01", "2019-02", "2019-03", "2019-04", "2019-05", "2019-06", "2019-07", "2019-08", "2019-09", "2019-10", "2019-11", "2019-12"], "y": [1937547, 923235, 481027, 1419420, 1260701, 703834, 242899, 0, 0, 721524, 240508, 975527, 1310276]}, {"line": {"shape": "spline"}, "name": "Say Love", "type": "scatter", "x": ["2018-12", "2019-01", "2019-02", "2019-03", "2019-04", "2019-05", "2019-06", "2019-07", "2019-08", "2019-09", "2019-10", "2019-11", "2019-12"], "y": [658320, 2212350, 224093, 2182342, 790318, 219440, 664158, 1106930, 221386, 221386, 0, 0, 3262]}, {"line": {"shape": "spline"}, "name": "Home", "type": "scatter", "x": ["2018-12", "2019-01", "2019-02", "2019-03", "2019-04", "2019-05", "2019-06", "2019-07", "2019-08", "2019-09", "2019-10", "2019-11", "2019-12"], "y": [810584, 2405242, 1422973, 629823, 189147, 920914, 537714, 225904, 606400, 0, 0, 1980, 303081]}, {"line": {"shape": "spline"}, "name": "Sweet Caroline", "type": "scatter", "x": ["2018-12", "2019-01", "2019-02", "2019-03", "2019-04", "2019-05", "2019-06", "2019-07", "2019-08", "2019-09", "2019-10", "2019-11", "2019-12"], "y": [405013, 2245503, 1113527, 1420744, 610227, 407281, 212326, 540964, 705746, 0, 202506, 202506, 57620]}, {"line": {"shape": "spline"}, "name": "Daylight", "type": "scatter", "x": ["2018-12", "2019-01", "2019-02", "2019-03", "2019-04", "2019-05", "2019-06", "2019-07", "2019-08", "2019-09", "2019-10", "2019-11", "2019-12"], "y": [342666, 1201583, 1216283, 847251, 964629, 3354291, 1022282, 676012, 0, 211990, 225400, 225306, 914785]}, {"line": {"shape": "spline"}, "name": "Viva La Vida", "type": "scatter", "x": ["2018-12", "2019-01", "2019-02", "2019-03", "2019-04", "2019-05", "2019-06", "2019-07", "2019-08", "2019-09", "2019-10", "2019-11", "2019-12"], "y": [155882, 1015208, 989274, 1525123, 886860, 1207685, 594157, 242372, 242373, 0, 484744, 484745, 242373]}, {"line": {"shape": "spline"}, "name": "Africa", "type": "scatter", "x": ["2018-12", "2019-01", "2019-02", "2019-03", "2019-04", "2019-05", "2019-06", "2019-07", "2019-08", "2019-09", "2019-10", "2019-11", "2019-12"], "y": [0, 2071251, 2962023, 1479465, 301233, 275702, 529255, 0, 295893, 0, 0, 295893, 295893]}, {"line": {"shape": "spline"}, "name": "False Alarm", "type": "scatter", "x": ["2018-12", "2019-01", "2019-02", "2019-03", "2019-04", "2019-05", "2019-06", "2019-07", "2019-08", "2019-09", "2019-10", "2019-11", "2019-12"], "y": [0, 907024, 0, 224271, 675575, 273349, 372601, 1056453, 686766, 1121355, 829063, 672813, 94612]}, {"line": {"shape": "spline"}, "name": "A Thousand Years", "type": "scatter", "x": ["2018-12", "2019-01", "2019-02", "2019-03", "2019-04", "2019-05", "2019-06", "2019-07", "2019-08", "2019-09", "2019-10", "2019-11", "2019-12"], "y": [0, 5995613, 1141644, 285120, 570240, 13747, 392959, 285120, 285120, 285120, 0, 570240, 0]}, {"line": {"shape": "spline"}, "name": "Wake Me Up", "type": "scatter", "x": ["2018-12", "2019-01", "2019-02", "2019-03", "2019-04", "2019-05", "2019-06", "2019-07", "2019-08", "2019-09", "2019-10", "2019-11", "2019-12"], "y": [0, 991776, 494853, 247426, 583982, 1708297, 1144861, 5546, 496756, 0, 957762, 497940, 494079]}, {"line": {"shape": "spline"}, "name": "I Like Me Better", "type": "scatter", "x": ["2018-12", "2019-01", "2019-02", "2019-03", "2019-04", "2019-05", "2019-06", "2019-07", "2019-08", "2019-09", "2019-10", "2019-11", "2019-12"], "y": [0, 584546, 789745, 0, 875578, 1649881, 413347, 604268, 809333, 231873, 533902, 197436, 412484]}, {"line": {"shape": "spline"}, "name": "Viva La Vida / Jas", "type" ...
#                         {"font": {"size": 12}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#f
